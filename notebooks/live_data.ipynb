# %%
import requests

# %%
url = "https://api.waqi.info/feed/chennai/?token=fa867b87d3aadf2160c7102257fe119ee4076334"

response = requests.get(url)
url = "https://api.waqi.info/feed/chennai/?token=YOUR_WAQI_TOKEN"
print(response.json())
# Out:
# {'status': 'ok', 'data': {'aqi': 38, 'idx': 13737, 'attributions': [{'url': 'http://cpcb.nic.in/', 'name': 'CPCB - India Central Pollution Control Board', 'logo': 'India-CPCB.png'}, {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}], 'city': {'geo': [13.1036, 80.2909], 'name': 'Royapuram, Chennai, Chennai, India', 'url': 'https://aqicn.org/city/chennai//royapuram', 'location': ''}, 'dominentpol': 'pm25', 'iaqi': {'co': {'v': 4.1}, 'dew': {'v': 27}, 'h': {'v': 81.5}, 'no2': {'v': 4.8}, 'o3': {'v': 7.1}, 'p': {'v': 730.4625}, 'pm10': {'v': 25}, 'pm25': {'v': 38}, 'so2': {'v': 2.3}, 't': {'v': 28.06}, 'w': {'v': 1.2275}}, 'time': {'s': '2026-04-04 18:00:00', 'tz': '+05:30', 'v': 1775325600, 'iso': '2026-04-04T18:00:00+05:30'}, 'forecast': {'daily': {'pm10': [{'avg': 21, 'day': '2026-04-02', 'max': 26, 'min': 19}, {'avg': 23, 'day': '2026-04-03', 'max': 28, 'min': 19}, {'avg': 29, 'day': '2026-04-04', 'max': 40, 'min': 19}, {'avg': 46, 'day': '2026-04-05', 'max': 4
# ...
